# %%
#import libraries and tools
import os
import pandas as pd
import numpy as np

# %%
train_dir = "C:\\Users\\user\\Desktop\\machine learning\\brain tumor dataset\\MRI_Images\\Training"
test_dir = "C:\\Users\\user\\Desktop\\machine learning\\brain tumor dataset\\MRI_Images\\Testing"

# %%
train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    for image in os.listdir(os.path.join(train_dir, label)):
      train_paths.append(os.path.join(train_dir, label, image))
      train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)

#load and shuffle the test data
test_paths = []
test_labels = []

for label in os.listdir(test_dir):
    for image in os.listdir(os.path.join(test_dir, label)):
      test_paths.append(os.path.join(test_dir, label, image))
      test_labels.append(label)

test_paths, test_labels = shuffle(test_paths, test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       5     for image in os.listdir(os.path.join(train_dir, label)):
#       6       train_paths.append(os.path.join(train_dir, label, image))
#       7       train_labels.append(label)
#       8
# ----> 9 train_paths, train_labels = shuffle(train_paths, train_labels)
#      10
#      11 #load and shuffle the test data
#      12 test_paths = []
#
# NameError: name 'shuffle' is not defined
